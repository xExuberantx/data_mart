# %%
import pandas as pd
sales_by_region = pd.read_csv(r'C:\Users\Kamil\Desktop\data_mart_pd\sales_by_region.csv')
sales_by_region.head()
# Out:
#    week_number  region  sales_per_week
# 0         13.0  AFRICA       152958541
# 1         14.0  AFRICA       142647377
# 2         15.0  AFRICA       143405192
# 3         16.0  AFRICA       150876528
# 4         17.0  AFRICA       131593844

# %%
sbr = sales_by_region.pivot_table(index='week_number', columns='region', values='sales_per_week',)
print(sbr)
sbr.to_csv(r'C:\Users\Kamil\Desktop\data_mart_pd\sbr_pivot.csv')
# Out:
# region            AFRICA         ASIA      CANADA     EUROPE      OCEANIA  \
# week_number
# 13.0         152958541.0  146971355.0  37798683.0  9029415.0  213209201.0
# 14.0         142647377.0  134444514.0  36932827.0  8916167.0  201965020.0
# 15.0         143405192.0  135621690.0  34685355.0  8585600.0  190941254.0
# 16.0         150876528.0  138254300.0  36563989.0  9104197.0  196281418.0
# 17.0         131593844.0  134927825.0  33738925.0  8827131.0  192833570.0
# 18.0         135265888.0  137135540.0  36254269.0  9284865.0  196651505.0
# 19.0         146280662.0  138236269.0  35644996.0  8886326.0  198257417.0
# 20.0         141036951.0  133864804.0  35215538.0  9138986.0  192714837.0
# 21.0         141125597.0  134815531.0  34853028.0  8943714.0  191813688.0
# 22.0         142158311.0  134960732.0  35316917.0  9430300.0  193680795.0
# 23.0         141169074.0  135024741.0  34047811.0  9349605.0  192399757.0
# ...
